# %% [markdown]
# # Penguins Bivariate Analysis

# %%
# import janitor
# import palmerpenguins

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import scipy.stats  # for t-test
import sklearn.metrics  # for confusion matrix

import empiricaldist  # for CDF

import scipy.stats as stats

import statsmodels.api as sm
import statsmodels.formula.api as smf
import statsmodels.stats as ss
# import session_info  # for session info

# %%
penguins_df: pd.DataFrame = sns.load_dataset("penguins")  # load the data
data: pd.DataFrame = penguins_df.copy()  # make a copy of the data to work with
